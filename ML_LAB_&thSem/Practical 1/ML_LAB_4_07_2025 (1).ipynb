# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns
# Replace 'path/to/your/file.csv' with the actual path to your CSV file in Google Drive
file_path = '/content/gdrive/MyDrive/ML_LAB_22070521130_7th_SEM/ML_LAB_4-07-2025-House_Price_Prediction.csv'
df = pd.read_csv(file_path)
print("CSV file imported successfully!")

df
# Out:
# CSV file imported successfully!
#     Area in Sq/m    Price
# 0            500  2000000
# 1            550  2050000
# 2            600  3000000
# 3            650  3050000
# 4            700  4000000
# 5            750  4050000
# 6            800  5000000
# 7            850  5050000
# 8            900  6000000
# 9            950  6050000
# 10          1000  7000000
# 11          1360   149919
# 12          4272   424998
# 13          3592   266746
# 14           966   244020
# 15          4926   636056
# 16          3944    93262
# 17          3671   448722
# 18          3419   594893
# 19           630   652878
# 20          2185   340375
# 21          1269   653685
# 22          2891   127123
# 23          2933   849947
# 24          1684   399355
# 25          3885   481838
# 26          4617   853032
# 27          3404   208964
# 28           974   905742
# 29          1582   989305
# 30          3058   218767
# 31          2547   996357
# 32          3247   709789
# ...

# %%
display(df.head())
# Out:
#    Area in Sq/m    Price
# 0           500  2000000
# 1           550  2050000
# 2           600  3000000
# 3           650  3050000
# 4           700  4000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area in Sq/m  41 non-null     int64
#  1   Price         41 non-null     int64
# dtypes: int64(2)
# memory usage: 788.0 bytes

# %%
df.shape
# Out:
# (41, 2)

# %%
df.head(5)
# Out:
#    Area in Sq/m    Price
# 0           500  2000000
# 1           550  2050000
# 2           600  3000000
# 3           650  3050000
# 4           700  4000000

# %%
df.tail(5)
# Out:
#     Area in Sq/m   Price
# 36          3234  527032
# 37          3505  745494
# 38          2399  513179
# 39          1767  948212
# 40          2028  206547

# %%
df.describe()
# Out:
#        Area in Sq/m         Price
# count     41.000000  4.100000e+01
# mean    2114.853659  1.543477e+06
# std     1323.981997  1.897837e+06
# min      500.000000  9.326200e+04
# 25%      900.000000  4.249980e+05
# 50%     1767.000000  6.886680e+05
# 75%     3247.000000  2.000000e+06
# max     4926.000000  7.000000e+06

# %%
df.isnull().sum()
# Out:
# Area in Sq/m    0
# Price           0
# dtype: int64

# %%
X = df[['Area in Sq/m']]
y = df['Price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)
y_pred
y_test=np.array(y_test)

# %%
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.3171806981117815

# %%
y_pred2=model.predict(X_train)
y_pred2
# Out:
# array([2376828.41848799, -798065.29891405,  542640.57420416,
#         -13924.04376093, 2585240.70728123, 1294042.73418286,
#        2736159.95089013,  417273.79512164, 2536531.32177783,
#        2049437.46674381, 2696234.22506767,  693559.81781306,
#        2122102.28774069, 2656308.49924521, 1101600.73571861,
#         336623.82896027, 2616382.77342275,  553021.262918  ,
#         793374.13236921, 1957608.29735215, 2336902.69266553,
#         826911.74206008,  405296.0773749 , 1390662.99067322,
#        2456679.87013291, 2364052.1862248 , 2357664.07009321,
#        1219780.88415309])

# %%
plt.figure(figsize=(10, 6))
plt.scatter(X_test, y_test, color='blue', label='Actual Price')
plt.plot(X_test, y_pred, color='red', linewidth=2, label='Regression Line')
plt.xlabel('Area in Sq/m')
plt.ylabel('Price')
plt.title('Linear Regression: Price vs Area')
plt.legend()
plt.grid(True)
plt.show()
